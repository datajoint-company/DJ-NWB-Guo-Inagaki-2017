# %%
from datetime import datetime
import os
os.chdir('..')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import datajoint as dj
from pipeline import reference, subject, acquisition, stimulation, analysis #, behavior, ephys, action
# Out:
# Connecting root@127.0.0.1:3306

# %% [markdown]
# ## Reproduce Figure 3b, e, f - Whole cell

# %%
# Get Cells with recording at ALM
alm_cells = (acquisition.Cell & {'brain_region':'ALM'}).fetch(dj.key)
(acquisition.Cell & {'brain_region':'ALM'})
# Out:
# *subject_id    *session_time  *cell_id      cell_type     brain_region   brain_subregio cortical_layer hemisphere     coordinate_ref coordinate_ap  coordinate_ml  coordinate_dv  device_name
# +------------+ +------------+ +-----------+ +-----------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+
# ANM324791      2017-05-20 19: cell_50_1     N/A           ALM            N/A            N/A            left           bregma         2.50           1.50           0.39           Multiclamp_700
# ANM324792      2017-05-20 19: cell_65_1     N/A           ALM            N/A            N/A            left           bregma         2.50           1.50           0.43           Multiclamp_700
# ANM300476      2017-05-20 18: cell_22_1     N/A           ALM            N/A            N/A            left           bregma         2.50           1.50           0.46           Multiclamp_700
# ANM300476      2017-05-20 18: cell_23_1     N/A           ALM            N/A            N/A            left           bregma         2.50           1.50           0.47           Multiclamp_700
# ANM322808      2017-05-20 19: cell_60_1     N/A           ALM            N/A            N/A            left           bregma         2.50           1.50           0.48           Multiclamp_700
# ANM300476      2017-05-20 18: cell_20_1     N/A           ALM            N/A            N/A            left           bregma         2.50           1.50           0.49           Multiclamp_700
# ANM322808      2017-05-20 19: cell_56_1     N/A           ALM            N/A            N/A            left           bregma         2.50           1.50           0.50           Multiclamp_700
#    ...
#  (15 tuples)
